# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ushape.csv", header=None)
df.head()
# Out:
#           0         1    2
# 0  0.031595  0.986988  0.0
# 1  2.115098 -0.046244  1.0
# 2  0.882490 -0.075756  0.0
# 3 -0.055144 -0.037332  1.0
# 4  0.829545 -0.539321  1.0

# %%
df.columns
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
df[0]
# Out:
# 0     0.031595
# 1     2.115098
# 2     0.882490
# 3    -0.055144
# 4     0.829545
#         ...
# 95    1.699453
# 96    0.218623
# 97    0.952914
# 98   -1.318500
# 99   -1.296818
# Name: 0, Length: 100, dtype: float64

# %%
plt.scatter(df[0],df[1],c=df[2])

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,-1].values

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2,activation='tanh',input_dim=2))
model.add(Dense(1,activation='tanh'))

model.summary()
# Out:
# c:\Users\vikas\OneDrive\Desktop\Deep-Learning-CampusX\campus\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set parameters to 0
model.get_weights()
# Out:
# [array([[-0.9144324 , -0.32187635],
#         [ 0.917488  , -0.9677701 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.72633684],
#         [-1.0266092 ]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights = model.get_weights()

# %%
initial_weights[0] = np.zeros(model.get_weights()[0].shape)*0.5
initial_weights[1] = np.zeros(model.get_weights()[1].shape)*0.5
initial_weights[2] = np.zeros(model.get_weights()[2].shape)*0.5
initial_weights[3] = np.zeros(model.get_weights()[3].shape)*0.5

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.],
#         [0.]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(X,y,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4766 - loss: 8.4368 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5156 - loss: 7.8072 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5391 - loss: 7.4294 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4883 - loss: 8.2479 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4688 - loss: 8.5627 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5273 - loss: 7.6183 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4922 - loss: 8.1850 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4805 - loss: 8.3739 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4766 - loss: 8.4368 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4844 - loss: 8.3109 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4844 - loss: 8.3109 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4844 - loss: 8.3109 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5234 - loss: 7.6813 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5273 - loss: 7.6183 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5156 - loss: 7.8072 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5195 - loss: 7.7442 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4609 - loss: 8.6887 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4883 - loss: 8.2479 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5352 - loss: 7.4924 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4648 - loss: 8.6257 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5195 - loss: 7.7442 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5391 - loss: 7.4294 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4922 - loss: 8.1850 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5391 - loss: 7.4294 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4727 - loss: 8.4998 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5312 - loss: 7.5554 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5312 - loss: 7.5554 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4727 - loss: 8.4998 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4766 - loss: 8.4368 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4570 - loss: 8.7516 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5352 - loss: 7.4924 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4570 - loss: 8.7516 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4922 - loss: 8.1850 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5117 - loss: 7.8702 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4844 - loss: 8.3109 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5039 - loss: 7.9961 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5391 - loss: 7.4294 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4766 - loss: 8.4368 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5234 - loss: 7.6813 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4805 - loss: 8.3739 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4727 - loss: 8.4998 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5156 - loss: 7.8072 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5156 - loss: 7.8072 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4883 - loss: 8.2479 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5352 - loss: 7.4924 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4922 - loss: 8.1850 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5078 - loss: 7.9331 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4844 - loss: 8.3109 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4844 - loss: 8.3109 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4727 - loss: 8.4998 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5234 - loss: 7.6813 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4766 - loss: 8.4368 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4961 - loss: 8.1220 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5156 - loss: 7.8072 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5312 - loss: 7.5554 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5000 - loss: 8.0590 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5156 - loss: 7.8072 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4727 - loss: 8.4998 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4844 - loss: 8.3109 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5117 - loss: 7.8702 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5234 - loss: 7.6813 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5195 - loss: 7.7442 - val_accuracy: 0.5000 - val_loss: 8.0590

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.],
#         [0.]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y.astype('int'), clf=model, legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 12s 1ms/step
# <Axes: >

# %%
print("The End")
# Out:
# The End
